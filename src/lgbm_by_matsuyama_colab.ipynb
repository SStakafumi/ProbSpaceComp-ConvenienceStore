# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/MyPython/ProbSpace/src
# Out:
# /content/drive/MyDrive/MyPython/ProbSpace/src

# %%
# !pip install sklego
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sklego in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-lego in /usr/local/lib/python3.7/dist-packages (from sklego) (0.6.13)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from scikit-lego->sklego) (0.5.3)
# Requirement already satisfied: umap-learn>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from scikit-lego->sklego) (0.5.3)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from scikit-lego->sklego) (1.3.5)
# Requirement already satisfied: autograd>=1.2 in /usr/local/lib/python3.7/dist-packages (from scikit-lego->sklego) (1.5)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.7/dist-packages (from scikit-lego->sklego) (1.0.2)
# Requirement already satisfied: Deprecated>=1.2.6 in /usr/local/lib/python3.7/dist-packages (from scikit-lego->sklego) (1.2.13)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.2->scikit-lego->sklego) (1.21.6)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.2->scikit-lego->sklego) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from Deprecated>=1.2.6->scikit-lego->sklego) (1.14.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->scikit-lego->sklego) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->scikit-lego->sklego) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->scikit-lego->sklego) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (3.1.0)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (0.56.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (4.64.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (0.5.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (4.13.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (0.39.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (4.1.1)

# %%
# Library
import os
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import statsmodels.api as sm
import lightgbm as lgb
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline

from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_pinball_loss
from sklearn.feature_selection import RFE
from sklearn.preprocessing import FunctionTransformer
from sklego.preprocessing import RepeatingBasisFunction
from tqdm.auto import tqdm

import warnings
warnings.simplefilter('ignore')

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
seed = 42

# %%
train_df = pd.read_csv('../data/train_data.csv')
test_df = pd.read_csv('../data/test_data.csv')
submission_df = pd.read_csv('../data/submission.csv')

# %%
test_df.tail()
# Out:
#     id  date  highest  lowest  rain
# 16  17  4/12     12.6     7.5   0.0
# 17  18  4/13     18.2     5.5   0.0
# 18  19  4/14     18.3     9.7   0.0
# 19  20  4/15     22.7    11.6   5.0
# 20  21  4/16     21.0    10.1   0.0

# %%
def preprocessing(df, mode='train'):
    df_tmp = df.copy()
    input_year = 2021

    df_tmp['time'] = pd.to_datetime(df_tmp.date, format='%m/%d')
    df_tmp['year'] = df_tmp['time'].dt.year
    df_tmp['month'] = df_tmp['time'].dt.month
    df_tmp['day'] = df_tmp['time'].dt.day
    if mode=='train':
        df_tmp.loc[df_tmp['month']>3, 'year'] = input_year
        df_tmp.loc[df_tmp['month']<=3, 'year'] = input_year + 1
    else:
        df_tmp['year'] = input_year + 1
    df_tmp['time'] = pd.to_datetime({'year':df_tmp.year, 'month':df_tmp.month, 'day':df_tmp.day})
    df_tmp['weekday'] = df_tmp['time'].dt.weekday
    return df_tmp

train_df = preprocessing(train_df, mode='train')
test_df = preprocessing(test_df, mode='test')

# %%
train_df.columns
# Out:
# Index(['id', 'date', 'highest', 'lowest', 'rain', 'ice1', 'ice2', 'ice3',
#        'oden1', 'oden2', 'oden3', 'oden4', 'hot1', 'hot2', 'hot3', 'dessert1',
#        'dessert2', 'dessert3', 'dessert4', 'dessert5', 'drink1', 'drink2',
#        'drink3', 'drink4', 'drink5', 'drink6', 'alcol1', 'alcol2', 'alcol3',
#        'snack1', 'snack2', 'snack3', 'bento1', 'bento2', 'bento3', 'bento4',
#        'tild1', 'tild2', 'men1', 'men2', 'men3', 'men4', 'men5', 'men6',
#        'time', 'year', 'month', 'day', 'weekday'],
#       dtype='object')

# %%
target_columns = ['ice1', 'ice2', 'ice3',
    'oden1', 'oden2', 'oden3', 'oden4', 'hot1', 'hot2', 'hot3', 'dessert1',
    'dessert2', 'dessert3', 'dessert4', 'dessert5', 'drink1', 'drink2',
    'drink3', 'drink4', 'drink5', 'drink6', 'alcol1', 'alcol2', 'alcol3',
    'snack1', 'snack2', 'snack3', 'bento1', 'bento2', 'bento3', 'bento4',
    'tild1', 'tild2', 'men1', 'men2', 'men3', 'men4', 'men5', 'men6']

# %%
all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
# sin,cos変換を適用
def sin_transformer(period):
    return FunctionTransformer(lambda x: np.sin(x / period * 2 * np.pi))

def cos_transformer(period):
    return FunctionTransformer(lambda x: np.cos(x / period * 2 * np.pi))

all_df_sincos = all_df.copy()
all_df_sincos['day_of_year'] = all_df.time.dt.day_of_year

# month -> sin, cos
all_df_sincos['month_sin'] = sin_transformer(12).fit_transform(all_df_sincos['month'])
all_df_sincos['month_cos'] = cos_transformer(12).fit_transform(all_df_sincos['month'])

# week -> sin, cos
all_df_sincos['weekday_sin'] = sin_transformer(7).fit_transform(all_df_sincos['weekday'])
all_df_sincos['weekday_cos'] = cos_transformer(7).fit_transform(all_df_sincos['weekday'])

# day -> sin, cos
all_df_sincos['day_sin'] = sin_transformer(365).fit_transform(all_df_sincos['day_of_year'])
all_df_sincos['day_cos'] = cos_transformer(365).fit_transform(all_df_sincos['day_of_year'])


fig, ax = plt.subplots(3, 1, sharex=True, figsize=(16,8))
all_df_sincos[["month_sin", "month_cos"]].plot(ax=ax[0])
all_df_sincos[["weekday_sin", "weekday_cos"]].plot(ax=ax[1])
all_df_sincos[["day_sin", "day_cos"]].plot(ax=ax[2])
plt.suptitle("Cyclical encoding with sine/cosine transformation")
# Out:
# Text(0.5, 0.98, 'Cyclical encoding with sine/cosine transformation')

# %%
# 放射状基底関数
all_df_sincos_rbf = all_df_sincos.copy()

rbf = RepeatingBasisFunction(n_periods=12, column='day_of_year', input_range=(1, 365), remainder='drop')
rbf.fit(all_df_sincos_rbf)

tmp_column = [f'month_rbf_{i}' for i in range(1, 13)]
day_of_year_rbf = pd.DataFrame(columns=tmp_column, data=rbf.transform(all_df_sincos_rbf))

# 放射状基底関数を結合
all_df_sincos_rbf = pd.merge(all_df_sincos_rbf, day_of_year_rbf, left_index=True, right_index=True)

# プロット
day_of_year_rbf.plot(subplots=True, figsize=(14, 8),
     	sharex=True, title="Radial Basis Functions",
     	legend=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f14e332f390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1e338d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e332f5d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1da2f10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1d68290>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1da0450>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1d58810>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1d10a90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1d10ad0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1cc8f10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e1c484d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f14e330a790>],
#       dtype=object)

# %%
all_df_sincos_rbf.head()
# Out:
#    id  date  highest  lowest  rain  ice1  ice2  ice3  oden1  oden2  oden3  \
# 0   1  4/11     21.9    12.4   0.0  25.0  72.0  26.0   10.0   23.0   52.0
# 1   2  4/12     25.9    13.9   0.0  30.0  85.0  33.0    9.0   18.0   42.0
# 2   3  4/13     20.9    11.9   0.0  21.0  68.0  28.0   12.0   22.0   57.0
# 3   4  4/14     18.8    11.4   0.0  19.0  62.0  35.0   13.0   29.0   62.0
# 4   5  4/15     22.1    13.5  19.0  21.0  72.0  32.0   10.0   24.0   44.0
#
#    oden4   hot1   hot2   hot3  dessert1  dessert2  dessert3  dessert4  \
# 0   35.0  180.0  254.0  270.0      42.0      58.0      50.0      59.0
# 1   26.0  202.0  219.0  235.0      22.0      36.0       5.0      28.0
# 2   31.0  164.0  210.0  223.0      20.0      41.0       5.0      30.0
# 3   33.0  193.0  242.0  251.0      21.0      43.0       5.0      28.0
# 4   33.0  218.0  271.0  274.0      44.0      63.0      47.0      59.0
#
#    dessert5  drink1  drink2  drink3  drink4  drink5  drink6  alcol1  alcol2  \
# 0      67.0    54.0    45.0    28.0    49.0    22.0     8.0    63.0    51.0
# 1      37.0    69.0    54.0    35.0    58.0    22.0     9.0    77.0    66.0
# 2      32.0    46.0    38.0    24.0    45.0    26.0     9.0    81.0    69.0
# 3      32.0    35.0    31.0    22.0    37.0    23.0     8.0    88.0    92.0
# 4      63.0    51.0    39.0    20.0    52.0    28.0    14.0   116.0   135.0
#
#    alcol3  snack1  snack2  snack3  bento1  bento2  bento3  bento4  tild1  \
# 0    59.0    26.0    21.0    35.0    56.0    46.0    70.0    27.0   12.0
# 1    72.0    36.0    32.0    63.0     8.0    14.0    23.0     9.0    5.0
# 2    74.0    36.0    25.0    57.0     9.0    12.0    19.0     6.0    4.0
# 3    81.0    20.0    10.0    45.0    54.0    43.0    74.0    28.0   15.0
# 4   119.0    31.0    21.0    39.0    52.0    36.0    69.0    26.0    4.0
#
#    tild2  men1  men2  men3  men4  men5  men6       time  year  month  day  \
# 0   12.0  57.0  30.0  41.0  38.0  37.0  35.0 2021-04-11  2021      4   11
# 1    8.0  19.0   9.0  13.0  26.0   4.0  16.0 2021-04-12  2021      4   12
# 2    9.0  23.0   9.0  11.0  33.0   4.0  13.0 2021-04-13  2021      4   13
# 3   17.0  55.0  35.0  46.0  46.0  51.0  46.0 2021-04-14  2021      4   14
# 4    9.0  54.0  33.0  39.0  40.0  41.0  40.0 2021-04-15  2021      4   15
#
#    weekday  day_of_year  month_sin  month_cos  weekday_sin  weekday_cos  \
# 0        6          101   0.866025       -0.5    -0.781831     0.623490
# 1        0          102   0.866025       -0.5     0.000000     1.000000
# 2        1          103   0.866025       -0.5     0.781831     0.623490
# 3        2          104   0.866025       -0.5     0.974928    -0.222521
# 4        3          105   0.866025       -0.5     0.433884    -0.900969
#
#     day_sin   day_cos  month_rbf_1  month_rbf_2  month_rbf_3  month_rbf_4  \
# 0  0.985948 -0.167052     0.000019     0.005119     0.186106     0.915731
# 1  0.982927 -0.183998     0.000015     0.004395     0.170670     0.897015
# 2  0.979614 -0.200891     0.000012     0.003765     0.156175     0.876774
# 3  0.976011 -0.217723     0.000010     0.003218     0.142600     0.855129
# 4  0.972118 -0.234491     0.000008     0.002745     0.129923     0.832208
#
#    month_rbf_5  month_rbf_6  month_rbf_7  month_rbf_8   month_rbf_9  \
# 0     0.609799     0.054956     0.000670     0.000001  2.471564e-10
# 1     0.638048     0.061421     0.000800     0.000001  3.366494e-10
# 2     0.666156     0.068498     0.000953     0.000002  4.575512e-10
# 3     0.693993     0.076224     0.001133     0.000002  6.205227e-10
# 4     0.721422     0.084637     0.001344     0.000003  8.397145e-10
#
#    month_rbf_10  month_rbf_11  month_rbf_12
# 0  7.472152e-15  6.543946e-13  9.598498e-09
# 1  1.087143e-14  4.609966e-13  7.222641e-09
# 2  1.578277e-14  3.240497e-13  5.423065e-09
# 3  2.286315e-14  2.272907e-13  4.063025e-09
# 4  3.304797e-14  1.590770e-13  3.037458e-09

# %%
# train, test に分ける
train_df_sincos_rbf = all_df_sincos_rbf.iloc[:350, :]
test_df_sincos_rbf = all_df_sincos_rbf.iloc[350:, :].dropna(axis=1)

# %%
# 検証データのindexを指定(訓練データの最後2ヶ月を使用)
valid_index = range(297,351) # month:2,3
# valid_index = range(325,351) # month:3

# 予測結果を保存する辞書型データ
results = dict({})
all_lgb_score = []

# 商品ごとの予測を作成

for c in tqdm(target_columns):
    train_tmp = train_df_sincos_rbf.copy()
    test_tmp = test_df_sincos_rbf.copy()
    
    #ice
    if c in ['ice1', 'ice2', 'ice3']:
        # 予測期間はアイスが人気な7, 8 ,9月ではないので除外
        train_tmp = train_tmp[~train_tmp['month'].isin([7, 8, 9])]
        # アイスは金曜に人気
        train_tmp['is_wday4'] = train_df['weekday'].isin([4]).astype(int)
        test_tmp['is_wday4'] = test_df['weekday'].isin([4]).astype(int)
    # oden
    elif c in ['oden1', 'oden2', 'oden3', 'oden4']:
        # おでんやって無い夏は考えない
        train_tmp = train_tmp[~train_tmp['month'].isin([7, 8, 9])]
        # おでんは水木で人気
        train_tmp['is_wday23'] = train_df['weekday'].isin([2, 3]).astype(int)
        test_tmp['is_wday23'] = test_df['weekday'].isin([2, 3]).astype(int)
    # hot
    elif c in ['hot1', 'hot2', 'hot3']:
        # ホットスナックは月、火、金で不人気
        train_tmp['is_wday014'] = train_df['weekday'].isin([0,1,4]).astype(int)
        test_tmp['is_wday014'] = test_df['weekday'].isin([0,1,4]).astype(int)
    # dessert
    elif c in ['dessert1', 'dessert2', 'dessert3', 'dessert4', 'dessert5']:
        # デザートは水曜と日曜で人気
        train_tmp['is_wday36'] = train_df['weekday'].isin([3,6]).astype(int)
        test_tmp['is_wday36'] = test_df['weekday'].isin([3,6]).astype(int)
    # drink1234
    elif c in ['drink1', 'drink2', 'drink3', 'drink4']:
        # 夏に人気なドリンクは夏のデータは使わない
        train_tmp = train_tmp[~train_tmp['month'].isin([7, 8, 9])]
        if c in ['drink1', 'drink4']:
            # 金曜に人気
            train_tmp['is_wday4'] = train_df['weekday'].isin([4]).astype(int)
            test_tmp['is_wday4'] = test_df['weekday'].isin([4]).astype(int)
        else:
            # 常に人気が変わらないドリンクは全期間つかう。火曜に人気
            train_tmp['is_wday1'] = train_df['weekday'].isin([1]).astype(int)
            test_tmp['is_wday1'] = test_df['weekday'].isin([1]).astype(int)
    # drink5
    elif c in ['drink5']:
        # 金曜に人気
        train_tmp['is_wday4'] = train_df['weekday'].isin([4]).astype(int)
        test_tmp['is_wday4'] = test_df['weekday'].isin([4]).astype(int)
    # drink6
    elif c in ['drink6']:
        # 日曜に人気
        train_tmp['is_wday6'] = train_df['weekday'].isin([6]).astype(int)
        test_tmp['is_wday6'] = test_df['weekday'].isin([6]).astype(int)
    # alcohol
    elif c in ['alcol1', 'alcol2', 'alcol3']:
        # 酒は水木で人気
        train_tmp['is_wday23'] = train_df['weekday'].isin([2, 3]).astype(int)
        test_tmp['is_wday23'] = test_df['weekday'].isin([2, 3]).astype(int)
    # snack
    elif c in ['snack1', 'snack2', 'snack3']:
        train_tmp['is_wday0'] = train_df['weekday'].isin([0]).astype(int)
        train_tmp['is_wday14'] = train_df['weekday'].isin([1,4]).astype(int)
        test_tmp['is_wday0'] = test_df['weekday'].isin([0]).astype(int)
        test_tmp['is_wday14'] = test_df['weekday'].isin([1,4]).astype(int)
    # bento
    elif c in ['bento1', 'bento2', 'bento3', 'bento4']:
        # 弁当は月、火、金で不人気
        train_tmp['is_wday014'] = train_df['weekday'].isin([0,1,4]).astype(int)
        test_tmp['is_wday014'] = test_df['weekday'].isin([0,1,4]).astype(int)
    # tild
    elif c in ['tild1', 'tild2']:
        # 日曜に人気
        train_tmp['is_wday6'] = train_df['weekday'].isin([6]).astype(int)
        test_tmp['is_wday6'] = test_df['weekday'].isin([6]).astype(int)
    # men
    elif c in ['men1', 'men2', 'men3', 'men4', 'men5', 'men6']:
        train_tmp['is_wday014'] = train_df['weekday'].isin([0,1,4]).astype(int)
        test_tmp['is_wday014'] = test_df['weekday'].isin([0,1,4]).astype(int)
    
    # 訓練に確実に不必要なデータを除く
    train_columns = [c for c in train_tmp.columns if c not in target_columns if c not in\
    # ['id', 'date', 'time', 'month', 'year', 'day', 'weekday', 'day_of_year']]
        ['id', 'date', 'time']]
    
    # データを訓練、検証に分割
    X_train = train_tmp[~train_tmp['id'].isin(valid_index)][train_columns]
    y_train = train_tmp[~train_tmp['id'].isin(valid_index)][c]
    X_valid = train_tmp[train_tmp['id'].isin(valid_index)][train_columns]
    y_valid = train_tmp[train_tmp['id'].isin(valid_index)][c]
     
    # テストデータ
    X_test = test_tmp[train_columns]

    # 分位点
    qs = np.array([0.01, 0.1, 0.5, 0.9, 0.99])
    
    # 分位点ごとのスコア
    q_scores = []
    
    # 分位点ごとにモデルを作成
    for q in qs:
        lgb = LGBMRegressor(
            objective='quantile',
            alpha = q,
            n_estimators=10000,
            colsample_bytree=0.9,
            random_state=seed,
            max_depth=5,
        )
        
        # RFEにより特徴量選択
        selector = RFE(lgb, n_features_to_select=0.6)
        selector.fit(X_train, y_train)
        
        # 特徴量が生き残ったか（残った：True、ドロップ：False）を表示
        result = pd.DataFrame(selector.get_support(), index=X_train.columns.values, columns=['left'])
        result['ranking'] = selector.ranking_
        print(f'---{c}_{q}---')
        display(result.T)
        print(' ')
        
        # このモデルで採用されたカラム
        train_columns_RFE = X_train.columns.values[selector.get_support()]
        
        # 採用されたカラムだけでデータを作成
        X_train_RFE = X_train[train_columns_RFE]
        X_valid_RFE = X_valid[train_columns_RFE]
        X_test_RFE = X_test[train_columns_RFE]
        
        
        # 学習
        lgb.fit(X_train_RFE, y_train, eval_set=(X_valid_RFE, y_valid), early_stopping_rounds=100, verbose=False)
        score = lgb.best_score_['valid_0']['quantile']
        
        y_pred = lgb.predict(X_test_RFE)
        results[(c, q)] = y_pred
        
        q_scores.append(score)

    all_lgb_score.append(q_scores)

score_df = pd.DataFrame(np.array(all_lgb_score), columns=qs, index=target_columns)
display(score_df)

print(f'ave score: {np.array(all_lgb_score).mean()}')
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# ---ice1_0.01---
#         highest lowest  rain   year month   day weekday day_of_year month_sin  \
# left       True   True  True  False  True  True    True        True      True
# ranking       1      1     1      4     1     1       1           1         1
#
#         month_cos weekday_sin weekday_cos day_sin day_cos month_rbf_1  \
# left        False       False       False   False    True        True
# ranking         3           7           9      11       1           1
#
#         month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5 month_rbf_6  \
# left           True        True        True        True        True
# ranking           1           1           1           1           1
#
#         month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10 month_rbf_11  \
# left           True       False       False        False        False
# ranking           1           2           5            6            8
#
#         month_rbf_12 is_wday4
# left           False    False
# ranking           10       12
#
# ---ice1_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      3     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           8           5            7
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            9            4        6
#
# ---ice1_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      8     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           5           4            7
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            6            3       10
#
# ---ice1_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      8     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           5           4           10
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            6            3        7
#
# ---ice1_0.99---
#         highest lowest   rain   year  month    day weekday day_of_year  \
# left      False  False  False  False  False  False   False       False
# ranking      12     11     10      9      8      7       6           5
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False       False        True    True    True
# ranking         4         3           2           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True        True        True
# ranking           1           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True        True        True         True
# ranking           1           1           1           1            1
#
#         month_rbf_11 month_rbf_12 is_wday4
# left            True         True     True
# ranking            1            1        1
#
# ---ice2_0.01---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1      8      4     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False       False        True   False    True
# ranking         6        11           3           1       9       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           5           7           10
#
#         month_rbf_11 month_rbf_12 is_wday4
# left            True         True    False
# ranking            1            1       12
#
# ---ice2_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           5            3
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            7            4        8
#
# ---ice2_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      7     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           2           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           5           4           11
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            6            3        8
#
# ---ice2_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      7     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           4            8
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            5            3        9
#
# ---ice2_0.99---
#         highest lowest   rain  year month   day weekday day_of_year month_sin  \
# left       True   True  False  True  True  True    True        True     False
# ranking       1      1      2     1     1     1       1           1         3
#
#         month_cos weekday_sin weekday_cos day_sin day_cos month_rbf_1  \
# left         True       False       False    True    True        True
# ranking         1           7           9       1       1           1
#
#         month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5 month_rbf_6  \
# left           True        True        True       False        True
# ranking           1           1           1           6           1
#
#         month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10 month_rbf_11  \
# left           True       False       False        False        False
# ranking           1           8          10           11            4
#
#         month_rbf_12 is_wday4
# left           False    False
# ranking            5       12
#
# ---ice3_0.01---
#         highest lowest   rain  year month   day weekday day_of_year month_sin  \
# left       True   True  False  True  True  True    True        True      True
# ranking       1      1      6     1     1     1       1           1         1
#
#         month_cos weekday_sin weekday_cos day_sin day_cos month_rbf_1  \
# left        False       False       False   False    True        True
# ranking         3           5           9      11       1           1
#
#         month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5 month_rbf_6  \
# left           True        True        True        True       False
# ranking           1           1           1           1           2
#
#         month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10 month_rbf_11  \
# left           True        True       False        False        False
# ranking           1           1           4            7            8
#
#         month_rbf_12 is_wday4
# left           False    False
# ranking           10       12
#
# ---ice3_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      7     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           4            5
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            8            3       10
#
# ---ice3_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      8     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           5           4            3
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            7            6        9
#
# ---ice3_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      3     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         6        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           7           5            9
#
#         month_rbf_11 month_rbf_12 is_wday4
# left           False        False    False
# ranking            8            4       10
#
# ---ice3_0.99---
#         highest lowest  rain  year month   day weekday day_of_year month_sin  \
# left       True   True  True  True  True  True    True        True     False
# ranking       1      1     1     1     1     1       1           1         3
#
#         month_cos weekday_sin weekday_cos day_sin day_cos month_rbf_1  \
# left        False       False       False    True   False        True
# ranking         5           7           9       1      12           1
#
#         month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5 month_rbf_6  \
# left           True        True        True        True        True
# ranking           1           1           1           1           1
#
#         month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10 month_rbf_11  \
# left           True       False       False        False        False
# ranking           1           2           4            6            8
#
#         month_rbf_12 is_wday4
# left           False    False
# ranking           10       11
#
# ---oden1_0.01---
#         highest lowest   rain   year  month   day weekday day_of_year  \
# left      False   True  False  False  False  True    True       False
# ranking      12      1      2     10      8     1       1           4
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False        True        True    True    True
# ranking         1         9           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           3           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           7           5            6
#
#         month_rbf_11 month_rbf_12 is_wday23
# left            True         True     False
# ranking            1            1        11
#
# ---oden1_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      8     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           2           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           7           4            9
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            6            5         3
#
# ---oden1_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           5            7
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            8            4         3
#
# ---oden1_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      5     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         7        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           9           6           10
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            8            4         3
#
# ---oden1_0.99---
#         highest lowest   rain   year  month   day weekday day_of_year  \
# left       True   True  False  False  False  True   False        True
# ranking       1      1      7     11      4     1       2           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False        True        True   False    True
# ranking         1         9           1           1       8       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True        True        True
# ranking           1           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           3           6           10
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False         True     False
# ranking            5            1        12
#
# ---oden2_0.01---
#         highest lowest   rain   year  month   day weekday day_of_year  \
# left       True   True  False  False  False  True    True       False
# ranking       1      1      5     12     11     1       1           2
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False        True       False    True    True
# ranking         1         8           1           3       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           9           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           4           6            7
#
#         month_rbf_11 month_rbf_12 is_wday23
# left            True         True     False
# ranking            1            1        10
#
# ---oden2_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      7     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           5           10
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            8            4         3
#
# ---oden2_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      7     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           4            8
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            9            5         3
#
# ---oden2_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      7     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         5        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           9           4           10
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            8            3         6
#
# ---oden2_0.99---
#         highest lowest   rain   year  month   day weekday day_of_year  \
# left       True   True  False  False  False  True    True        True
# ranking       1      1     10      9      5     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False       False        True    True    True
# ranking        12         8           4           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           3           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1           2           1           6            7
#
#         month_rbf_11 month_rbf_12 is_wday23
# left            True         True     False
# ranking            1            1        11
#
# ---oden3_0.01---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True       False
# ranking       1      1     1     12      9     1       1           6
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False        True       False    True    True
# ranking         1        11           1           3       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           8           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           7           2           10
#
#         month_rbf_11 month_rbf_12 is_wday23
# left            True        False     False
# ranking            1            4         5
#
# ---oden3_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      8     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           2           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           4            9
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            7            5         3
#
# ---oden3_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      8     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True        True        True
# ranking           1           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           2           6           5            9
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            7            4         3
#
# ---oden3_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         6        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           8           4           10
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            7            5         3
#
# ---oden3_0.99---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     11      2     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False       False       False    True    True
# ranking         9         5           8           4       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False       False
# ranking           1           1           1           3           6
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True        True        True        False
# ranking           1           1           1           1            7
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False         True     False
# ranking           10            1        12
#
# ---oden4_0.01---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True   False       False
# ranking       1      1     1     12     11     1       3           4
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False        True        True    True    True
# ranking         1        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           7           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           8           9            6
#
#         month_rbf_11 month_rbf_12 is_wday23
# left            True        False     False
# ranking            1            5         2
#
# ---oden4_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           4            8
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            7            5         3
#
# ---oden4_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           6           5            7
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            8            4         3
#
# ---oden4_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      3     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           5           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           8           6           10
#
#         month_rbf_11 month_rbf_12 is_wday23
# left           False        False     False
# ranking            7            2         4
#
# ---oden4_0.99---
#         highest lowest   rain   year  month   day weekday day_of_year  \
# left       True   True  False  False  False  True   False        True
# ranking       1      1     10      9      2     1       3           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        12         8           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           5           6            7
#
#         month_rbf_11 month_rbf_12 is_wday23
# left            True         True     False
# ranking            1            1        11
#
# ---hot1_0.01---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False       False       False    True    True
# ranking         3        11           7           6       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           8           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1          10           1           2            5
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True       True
# ranking            4            1          1
#
# ---hot1_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12     10     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           3           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           5           2           7            8
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            4            1          6
#
# ---hot1_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True       False        True
# ranking           3           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1           8           1           7            5
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            2            1          6
#
# ---hot1_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12     10     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         8        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           9           3           5            7
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True        False      False
# ranking            1            2          6
#
# ---hot1_0.99---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True       False
# ranking       1      1     1     12     10     1       1           3
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True      True        True       False    True   False
# ranking         1         1           1           6       1       2
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False       False        True        True        True
# ranking           7          11           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False         True
# ranking           1           9           8           4            1
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True         True      False
# ranking            1            1          5
#
# ---hot2_0.01---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      4     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False       False        True    True    True
# ranking         7        11           5           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           3           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True        True        False
# ranking           1          10           1           1            9
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False        False      False
# ranking            2            8          6
#
# ---hot2_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           8           2           7            5
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          6
#
# ---hot2_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           5           2           8            6
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          7
#
# ---hot2_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12     11     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True       False        True
# ranking           2           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1           6           1           8            7
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          5
#
# ---hot2_0.99---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True       False
# ranking       1      1     1     12     10     1       1           4
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False        True       False    True    True
# ranking         1        11           1           5       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False       False        True        True        True
# ranking           6           2           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1           7           9            3
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True         True      False
# ranking            1            1          8
#
# ---hot3_0.01---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      6     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False       False       False    True    True
# ranking         3        11           4           2       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False       False
# ranking           1           1           1           9           5
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1           7           1           8           10
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True         True       True
# ranking            1            1          1
#
# ---hot3_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False       False
# ranking           1           1           1           4           2
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           6           3           7            8
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True         True      False
# ranking            1            1          5
#
# ---hot3_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ...
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           7           2           8            6
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          5
#
# ---men4_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        10        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           8           2           7            6
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          5
#
# ---men4_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12     10     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           7           4           6            8
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          5
#
# ---men4_0.99---
#         highest lowest   rain   year  month   day weekday day_of_year  \
# left       True   True  False  False  False  True    True       False
# ranking       1      1      2     11     12     1       1          10
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False        True        True    True   False
# ranking         1         6           1           1       1       7
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False       False       False        True        True
# ranking           9           8           5           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True        True        True         True
# ranking           1           1           1           1            1
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True        False      False
# ranking            1            3          4
#
# ---men5_0.01---
#         highest lowest   rain   year  month   day weekday day_of_year  \
# left      False   True  False  False  False  True    True        True
# ranking       7      1      2     12     10     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False       False        True    True    True
# ranking         1         9           6           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True       False        True        True
# ranking           1           1           3           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1          11           1           4            8
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True         True      False
# ranking            1            1          5
#
# ---men5_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           5           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           8           3           6            7
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True        False      False
# ranking            1            2          4
#
# ---men5_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12     10     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11         9           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True       False        True
# ranking           4           1           1           2           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1           7           1           8            6
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          5
#
# ---men5_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12     10     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        11           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           2           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           8           4           5            6
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          7
#
# ---men5_0.99---
#         highest lowest   rain   year  month   day weekday day_of_year  \
# left       True   True  False  False  False  True    True        True
# ranking       1      1      4     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left         True     False        True       False    True    True
# ranking         1         5           1           2       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True       False        True
# ranking           8           1           1           3           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True       False       False        False
# ranking           1           1          10          11            7
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True         True      False
# ranking            1            1          6
#
# ---men6_0.01---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12     11     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         8        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True        True        True
# ranking           7           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left          False        True        True       False        False
# ranking           2           1           1           3            9
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False        False      False
# ranking            4            5          6
#
# ---men6_0.1---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left          False        True        True       False        True
# ranking           2           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1           8           1           7            6
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          5
#
# ---men6_0.5---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12      9     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking        11        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           4           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False        True       False        False
# ranking           1           6           1           8            7
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False        False      False
# ranking            2            3          5
#
# ---men6_0.9---
#         highest lowest  rain   year  month   day weekday day_of_year  \
# left       True   True  True  False  False  True    True        True
# ranking       1      1     1     12     11     1       1           1
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False        True        True    True    True
# ranking         9        10           1           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True       False        True
# ranking           1           1           1           2           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True       False       False       False        False
# ranking           1           6           4           8            5
#
#         month_rbf_11 month_rbf_12 is_wday014
# left           False         True      False
# ranking            3            1          7
#
# ---men6_0.99---
#         highest lowest   rain   year  month    day weekday day_of_year  \
# left      False  False  False  False  False  False   False       False
# ranking      12     11     10      9      8      7       6           5
#
#         month_sin month_cos weekday_sin weekday_cos day_sin day_cos  \
# left        False     False       False        True    True    True
# ranking         4         3           2           1       1       1
#
#         month_rbf_1 month_rbf_2 month_rbf_3 month_rbf_4 month_rbf_5  \
# left           True        True        True        True        True
# ranking           1           1           1           1           1
#
#         month_rbf_6 month_rbf_7 month_rbf_8 month_rbf_9 month_rbf_10  \
# left           True        True        True        True         True
# ranking           1           1           1           1            1
#
#         month_rbf_11 month_rbf_12 is_wday014
# left            True         True       True
# ranking            1            1          1
#               0.01      0.10      0.50      0.90      0.99
# ice1      0.060905  0.287129  0.780393  0.352219  0.695926
# ice2      0.363385  1.068580  1.948731  0.467798  0.419630
# ice3      0.070506  0.491150  1.180090  0.427386  0.257092
# oden1     0.611076  1.607214  5.284758  2.490023  0.645114
# oden2     0.578204  1.955276  5.860452  5.276919  3.847026
# oden3     1.028167  2.643745  5.843441  5.198357  0.779599
# oden4     0.589650  2.234531  4.243614  3.404247  0.743349
# hot1      0.529771  2.196553  4.056772  1.864046  0.924023
# hot2      0.399545  2.721673  6.017107  3.105409  0.564898
# hot3      0.423050  2.145153  5.628970  2.606960  0.698523
# dessert1  0.107162  0.478093  0.972001  0.461067  0.186179
# dessert2  0.143148  0.621436  1.436469  0.899754  0.200687
# dessert3  0.050169  0.499431  0.681723  0.626067  0.157225
# dessert4  0.121185  0.497345  1.175065  0.625471  0.162834
# dessert5  0.139519  0.779195  1.641102  0.699852  0.244295
# drink1    0.070222  0.412821  1.469210  0.778738  0.299730
# drink2    0.161796  0.589069  1.517856  1.063966  0.288625
# drink3    0.052290  0.303223  0.506403  0.597353  0.176883
# drink4    0.058053  0.369132  1.204007  0.509588  0.180222
# drink5    0.037845  0.326729  1.066434  0.584590  0.336587
# drink6    0.042761  0.294833  0.942583  0.628435  0.398583
# alcol1    0.283619  0.651615  1.474791  0.609181  0.178489
# alcol2    0.278184  0.763681  2.337034  0.990258  0.598192
# alcol3    0.196860  0.775647  2.150099  0.804362  0.436066
# snack1    0.093118  0.587204  1.558754  0.901851  0.346905
# snack2    0.133344  0.305016  0.692578  0.394026  0.164815
# snack3    0.169975  1.020956  2.376082  1.016726  0.154915
# bento1    0.214512  0.416440  0.983123  0.506425  0.078291
# bento2    0.215881  0.522754  1.573089  0.744419  0.195677
# bento3    0.342706  0.706704  1.575890  0.887576  0.250928
# bento4    0.067426  0.264208  0.622469  0.368812  0.134930
# tild1     0.072155  0.266144  0.713641  0.771840  0.099181
# tild2     0.031630  0.211091  0.613659  0.432418  0.269444
# men1      0.244696  0.786351  1.704607  1.172232  0.316049
# men2      0.141726  0.389673  0.820630  0.469654  0.146659
# men3      0.173578  0.509943  1.444443  0.783360  0.799074
# men4      0.122590  0.821859  2.050453  1.392737  0.221458
# men5      0.208583  0.466382  1.383906  0.674416  0.275423
# men6      0.169540  0.631047  1.876253  1.731677  0.315255
# ave score: 0.9504371257744294

# %%
submit_rows = [[f'{k[0]}_{k[1]}'] + v.tolist() for k, v in results.items()]

# %%
# submitファイルを作成
# データを整数に丸めることでわずかに精度が上がるらしい
submit_df = pd.DataFrame(np.array(submit_rows)[:, 1:22].astype(float).round(), index=np.array(submit_rows)[:, 0])
# 転置
submit_df = submit_df.transpose()
submit_df.index.name = 'id'
submit_df.to_csv("../work/submission/sub_lgb_kotrying_sincos_rbf_by_matsuyama_valid_23.csv")
display(submit_df.head())
# Out:
#     ice1_0.01  ice1_0.1  ice1_0.5  ice1_0.9  ice1_0.99  ice2_0.01  ice2_0.1  \
# id
# 0        15.0      19.0      21.0      23.0       88.0       37.0      59.0
# 1        15.0      18.0      20.0      22.0       88.0       37.0      55.0
# 2        14.0      15.0      16.0      20.0       88.0       26.0      33.0
# 3        15.0      17.0      17.0      20.0       88.0       37.0      41.0
# 4        15.0      17.0      19.0      22.0       88.0       37.0      51.0
#
#     ice2_0.5  ice2_0.9  ice2_0.99  ice3_0.01  ice3_0.1  ice3_0.5  ice3_0.9  \
# id
# 0       58.0      64.0       90.0       24.0      26.0      30.0      33.0
# 1       56.0      57.0       90.0       24.0      26.0      30.0      32.0
# 2       40.0      39.0       90.0       24.0      26.0      29.0      31.0
# 3       45.0      44.0       90.0       24.0      26.0      30.0      32.0
# 4       54.0      56.0       90.0       24.0      26.0      30.0      32.0
#
#     ice3_0.99  oden1_0.01  oden1_0.1  oden1_0.5  oden1_0.9  oden1_0.99  \
# id
# 0        55.0         6.0       38.0       46.0       64.0       100.0
# 1        55.0         6.0       22.0       16.0       64.0       100.0
# 2        55.0         6.0       41.0       47.0       74.0       100.0
# 3        55.0         6.0       41.0       43.0       74.0       100.0
# 4        55.0         6.0       37.0       45.0       64.0       100.0
#
#     oden2_0.01  oden2_0.1  oden2_0.5  oden2_0.9  oden2_0.99  oden3_0.01  \
# id
# 0         21.0       37.0       53.0       64.0       120.0        49.0
# 1         21.0       30.0       36.0       58.0       120.0        45.0
# 2         21.0       46.0       62.0       64.0       120.0        46.0
# 3         21.0       43.0       61.0       64.0       120.0        44.0
# 4         21.0       37.0       53.0       64.0       120.0        44.0
#
#     oden3_0.1  oden3_0.5  oden3_0.9  oden3_0.99  oden4_0.01  oden4_0.1  \
# id
# 0        96.0      118.0      151.0       210.0        32.0       45.0
# 1        78.0       90.0      151.0       210.0        32.0       40.0
# 2       103.0      106.0      180.0       241.0        32.0       64.0
# 3       101.0      107.0      180.0       210.0        34.0       63.0
# 4        88.0      107.0      151.0       210.0        35.0       46.0
#
#     oden4_0.5  oden4_0.9  oden4_0.99  hot1_0.01  hot1_0.1  hot1_0.5  hot1_0.9  \
# id
# 0        60.0       75.0       144.0       80.0     132.0     158.0     164.0
# 1        51.0       59.0       144.0       80.0     143.0     145.0     155.0
# 2        69.0       77.0       144.0       80.0     123.0     140.0     165.0
# 3        66.0       77.0       144.0       80.0     126.0     157.0     170.0
# 4        64.0       75.0       144.0       80.0     132.0     154.0     168.0
#
#     hot1_0.99  hot2_0.01  hot2_0.1  hot2_0.5  hot2_0.9  hot2_0.99  hot3_0.01  \
# id
# 0       210.0      178.0     215.0     219.0     242.0      268.0      184.0
# 1       211.0      178.0     208.0     213.0     230.0      268.0      184.0
# 2       210.0      178.0     196.0     206.0     232.0      268.0      184.0
# 3       210.0      178.0     209.0     217.0     243.0      268.0      184.0
# 4       210.0      178.0     211.0     216.0     247.0      268.0      184.0
#
#     hot3_0.1  hot3_0.5  hot3_0.9  hot3_0.99  dessert1_0.01  dessert1_0.1  \
# id
# 0      221.0     241.0     255.0      283.0           19.0          44.0
# 1      207.0     225.0     245.0      281.0           19.0          27.0
# 2      198.0     224.0     241.0      281.0           19.0          26.0
# 3      212.0     236.0     254.0      283.0           19.0          26.0
# 4      216.0     234.0     254.0      283.0           19.0          41.0
#
#     dessert1_0.5  dessert1_0.9  dessert1_0.99  dessert2_0.01  dessert2_0.1  \
# id
# 0           51.0          56.0           41.0           36.0          66.0
# 1           32.0          32.0           38.0           36.0          49.0
# 2           27.0          31.0           38.0           36.0          43.0
# 3           29.0          31.0           38.0           36.0          45.0
# 4           46.0          47.0           38.0           36.0          61.0
#
#     dessert2_0.5  dessert2_0.9  dessert2_0.99  dessert3_0.01  dessert3_0.1  \
# id
# 0           75.0          79.0           67.0            8.0          15.0
# 1           53.0          58.0           66.0            5.0           7.0
# 2           48.0          53.0           65.0            5.0           7.0
# 3           50.0          53.0           65.0            5.0           7.0
# 4           65.0          70.0           65.0           37.0          36.0
#
#     dessert3_0.5  dessert3_0.9  dessert3_0.99  dessert4_0.01  dessert4_0.1  \
# id
# 0           56.0          58.0           18.0           25.0          53.0
# 1           11.0          11.0           16.0           25.0          28.0
# 2            7.0          12.0           16.0           25.0          28.0
# 3            7.0          11.0           16.0           25.0          28.0
# 4           42.0          47.0           16.0           25.0          51.0
#
#     dessert4_0.5  dessert4_0.9  dessert4_0.99  dessert5_0.01  dessert5_0.1  \
# id
# 0           60.0          65.0           47.0           32.0          64.0
# 1           32.0          34.0           43.0           32.0          37.0
# 2           30.0          33.0           45.0           32.0          35.0
# 3           30.0          32.0           45.0           32.0          35.0
# 4           53.0          58.0           45.0           32.0          61.0
#
#     dessert5_0.5  dessert5_0.9  dessert5_0.99  drink1_0.01  drink1_0.1  \
# id
# 0           76.0          84.0           65.0         31.0        31.0
# 1           38.0          41.0           65.0         20.0        23.0
# 2           35.0          42.0           65.0         16.0        16.0
# 3           36.0          43.0           65.0         13.0        11.0
# 4           63.0          67.0           65.0         19.0        18.0
#
#     drink1_0.5  drink1_0.9  drink1_0.99  drink2_0.01  drink2_0.1  drink2_0.5  \
# id
# 0         36.0        39.0         51.0         17.0        28.0        31.0
# 1         26.0        30.0         51.0         17.0        25.0        28.0
# 2         21.0        21.0         42.0         17.0        21.0        25.0
# 3         16.0        21.0         42.0         17.0        18.0        20.0
# 4         18.0        24.0         51.0         17.0        19.0        24.0
#
#     drink2_0.9  drink2_0.99  drink3_0.01  drink3_0.1  drink3_0.5  drink3_0.9  \
# id
# 0         37.0         55.0         11.0        19.0        20.0        23.0
# 1         33.0         55.0         11.0        16.0        19.0        24.0
# 2         33.0         55.0         11.0        14.0        15.0        34.0
# 3         29.0         55.0         11.0        10.0        11.0        24.0
# 4         27.0         55.0         11.0        12.0        13.0        18.0
#
#     drink3_0.99  drink4_0.01  drink4_0.1  drink4_0.5  drink4_0.9  drink4_0.99  \
# id
# 0          32.0         28.0        37.0        33.0        42.0         51.0
# 1          32.0         28.0        33.0        32.0        37.0         51.0
# 2          32.0         27.0        28.0        30.0        35.0         51.0
# 3          32.0         27.0        28.0        30.0        35.0         51.0
# 4          32.0         28.0        31.0        31.0        36.0         50.0
#
#     drink5_0.01  drink5_0.1  drink5_0.5  drink5_0.9  drink5_0.99  drink6_0.01  \
# id
# 0          22.0        22.0        24.0        26.0         30.0          7.0
# 1          22.0        22.0        24.0        26.0         30.0          7.0
# 2          22.0        23.0        24.0        29.0         31.0          7.0
# 3          22.0        24.0        25.0        27.0         30.0          7.0
# 4          22.0        23.0        25.0        27.0         30.0          7.0
#
#     drink6_0.1  drink6_0.5  drink6_0.9  drink6_0.99  alcol1_0.01  alcol1_0.1  \
# id
# 0          7.0         8.0         9.0         16.0         45.0        55.0
# 1          7.0         8.0         9.0         16.0         45.0        65.0
# 2          7.0         9.0        18.0         20.0         45.0        75.0
# 3         10.0        11.0        11.0         16.0         45.0        84.0
# 4          9.0         9.0        10.0         16.0         37.0        93.0
#
#     alcol1_0.5  alcol1_0.9  alcol1_0.99  alcol2_0.01  alcol2_0.1  alcol2_0.5  \
# id
# 0         61.0        62.0         88.0         30.0        45.0        49.0
# 1         71.0        74.0         87.0         37.0        58.0        61.0
# 2         81.0        87.0         87.0         37.0        68.0        73.0
# 3         90.0        97.0         88.0         37.0        82.0        92.0
# 4         98.0       107.0         89.0         80.0        97.0       104.0
#
#     alcol2_0.9  alcol2_0.99  alcol3_0.01  alcol3_0.1  alcol3_0.5  alcol3_0.9  \
# id
# 0         51.0        104.0         43.0        54.0        56.0        59.0
# 1         65.0        104.0         61.0        63.0        70.0        74.0
# 2         83.0        102.0         61.0        73.0        76.0        83.0
# 3        100.0        102.0         61.0        81.0        91.0        95.0
# 4        107.0        108.0         61.0        93.0       101.0       109.0
#
#     alcol3_0.99  snack1_0.01  snack1_0.1  snack1_0.5  snack1_0.9  snack1_0.99  \
# id
# 0         119.0         19.0        23.0        28.0        32.0         42.0
# 1         119.0         19.0        29.0        32.0        39.0         42.0
# 2         119.0         19.0        27.0        32.0        37.0         42.0
# 3         119.0         17.0        18.0        23.0        28.0         42.0
# 4         119.0         19.0        24.0        26.0        31.0         42.0
#
#     snack2_0.01  snack2_0.1  snack2_0.5  snack2_0.9  snack2_0.99  snack3_0.01  \
# id
# 0           9.0        17.0        20.0        21.0         37.0         27.0
# 1           9.0        28.0        32.0        36.0         37.0         27.0
# 2           9.0        22.0        25.0        26.0         37.0         27.0
# 3           9.0        10.0        11.0        12.0         37.0         27.0
# 4           9.0        19.0        20.0        22.0         37.0         27.0
#
#     snack3_0.1  snack3_0.5  snack3_0.9  snack3_0.99  bento1_0.01  bento1_0.1  \
# id
# 0         35.0        43.0        45.0         56.0         14.0        44.0
# 1         41.0        54.0        59.0         62.0         14.0         9.0
# 2         40.0        50.0        55.0         58.0         14.0         9.0
# 3         32.0        40.0        42.0         58.0         14.0        45.0
# 4         38.0        43.0        48.0         58.0         14.0        44.0
#
#     bento1_0.5  bento1_0.9  bento1_0.99  bento2_0.01  bento2_0.1  bento2_0.5  \
# id
# 0         51.0        53.0         57.0          9.0        37.0        42.0
# 1         11.0        12.0         57.0          9.0        12.0        15.0
# 2         10.0        13.0         56.0          9.0        12.0        14.0
# 3         50.0        52.0         56.0          9.0        38.0        44.0
# 4         50.0        52.0         57.0          9.0        35.0        42.0
#
#     bento2_0.9  bento2_0.99  bento3_0.01  bento3_0.1  bento3_0.5  bento3_0.9  \
# id
# 0         46.0         50.0         15.0        59.0        71.0        78.0
# 1         17.0         50.0         15.0        18.0        20.0        23.0
# 2         18.0         50.0         16.0        18.0        21.0        25.0
# 3         51.0         50.0         15.0        64.0        71.0        76.0
# 4         46.0         50.0         15.0        65.0        68.0        72.0
#
#     bento3_0.99  bento4_0.01  bento4_0.1  bento4_0.5  bento4_0.9  bento4_0.99  \
# id
# 0          80.0         17.0        24.0        28.0        31.0         33.0
# 1          68.0         17.0         8.0         9.0        11.0         33.0
# 2          61.0         17.0         8.0         9.0        11.0         33.0
# 3          77.0         17.0        26.0        29.0        31.0         33.0
# 4          76.0         17.0        26.0        26.0        29.0         33.0
#
#     tild1_0.01  tild1_0.1  tild1_0.5  tild1_0.9  tild1_0.99  tild2_0.01  \
# id
# 0          4.0       11.0       13.0       20.0        20.0         6.0
# 1          4.0        4.0        5.0       12.0        17.0         6.0
# 2          4.0        4.0        5.0       11.0        18.0         6.0
# 3          4.0        4.0        5.0        8.0        16.0         6.0
# 4          4.0        4.0        5.0        9.0        16.0         6.0
#
#     tild2_0.1  tild2_0.5  tild2_0.9  tild2_0.99  men1_0.01  men1_0.1  \
# id
# 0         9.0       11.0       15.0        18.0       17.0      46.0
# 1         7.0        8.0       13.0        18.0       17.0      18.0
# 2         7.0        8.0       13.0        18.0       17.0      19.0
# 3         7.0        8.0       11.0        18.0       17.0      44.0
# 4         7.0        9.0       11.0        18.0       17.0      43.0
#
#     men1_0.5  men1_0.9  men1_0.99  men2_0.01  men2_0.1  men2_0.5  men2_0.9  \
# id
# 0       52.0      62.0       71.0        8.0      26.0      30.0      34.0
# 1       21.0      25.0       71.0        8.0       9.0      10.0      13.0
# 2       21.0      27.0       71.0        8.0       9.0      10.0      14.0
# 3       50.0      56.0       71.0        8.0      25.0      31.0      35.0
# 4       50.0      56.0       71.0       10.0      27.0      30.0      35.0
#
#     men2_0.99  men3_0.01  men3_0.1  men3_0.5  men3_0.9  men3_0.99  men4_0.01  \
# id
# 0        36.0       11.0      32.0      36.0      46.0       54.0       25.0
# 1        36.0       10.0      11.0      13.0      15.0       54.0       23.0
# 2        36.0       10.0      11.0      13.0      20.0       54.0       25.0
# 3        36.0       11.0      33.0      37.0      41.0       54.0       25.0
# 4        36.0       11.0      31.0      37.0      41.0       54.0       25.0
#
#     men4_0.1  men4_0.5  men4_0.9  men4_0.99  men5_0.01  men5_0.1  men5_0.5  \
# id
# 0       35.0      40.0      47.0       59.0        3.0      35.0      39.0
# 1       25.0      30.0      36.0       59.0        3.0       3.0       4.0
# 2       26.0      31.0      37.0       59.0        3.0       4.0       4.0
# 3       35.0      41.0      42.0       59.0        3.0      35.0      41.0
# 4       35.0      41.0      43.0       59.0        8.0      33.0      41.0
#
#     men5_0.9  men5_0.99  men6_0.01  men6_0.1  men6_0.5  men6_0.9  men6_0.99
# id
# 0       44.0       51.0       13.0      31.0      37.0      52.0       61.0
# 1        6.0       51.0       13.0      14.0      16.0      24.0       61.0
# 2        9.0       51.0       13.0      14.0      16.0      30.0       61.0
# 3       42.0       51.0       13.0      31.0      34.0      35.0       61.0
# 4       42.0       51.0       13.0      32.0      35.0      36.0       61.0

# %%
# 目視確認
pred_median_col = [c for c in submit_df.columns if '_0.5' in c]
test_add_pred = test_df.merge(submit_df[pred_median_col].reset_index(), on='id', how='left')
test_add_pred.columns = [c.replace('_0.5', '') if '_0.5' in c else c for c in test_add_pred.columns]
test_add_pred[target_columns] = test_add_pred[target_columns].astype(float)
test_add_pred.head(3)
# Out:
#    id  date  highest  lowest  rain       time  year  month  day  weekday  \
# 0   1  3/27     19.7     7.3   0.0 2022-03-27  2022      3   27        6
# 1   2  3/28     16.9     9.0   0.0 2022-03-28  2022      3   28        0
# 2   3  3/29      9.3     6.8   0.0 2022-03-29  2022      3   29        1
#
#    ice1  ice2  ice3  oden1  oden2  oden3  oden4   hot1   hot2   hot3  \
# 0  20.0  56.0  30.0   16.0   36.0   90.0   51.0  145.0  213.0  225.0
# 1  16.0  40.0  29.0   47.0   62.0  106.0   69.0  140.0  206.0  224.0
# 2  17.0  45.0  30.0   43.0   61.0  107.0   66.0  157.0  217.0  236.0
#
#    dessert1  dessert2  dessert3  dessert4  dessert5  drink1  drink2  drink3  \
# 0      32.0      53.0      11.0      32.0      38.0    26.0    28.0    19.0
# 1      27.0      48.0       7.0      30.0      35.0    21.0    25.0    15.0
# 2      29.0      50.0       7.0      30.0      36.0    16.0    20.0    11.0
#
#    drink4  drink5  drink6  alcol1  alcol2  alcol3  snack1  snack2  snack3  \
# 0    32.0    24.0     8.0    71.0    61.0    70.0    32.0    32.0    54.0
# 1    30.0    24.0     9.0    81.0    73.0    76.0    32.0    25.0    50.0
# 2    30.0    25.0    11.0    90.0    92.0    91.0    23.0    11.0    40.0
#
#    bento1  bento2  bento3  bento4  tild1  tild2  men1  men2  men3  men4  men5  \
# 0    11.0    15.0    20.0     9.0    5.0    8.0  21.0  10.0  13.0  30.0   4.0
# 1    10.0    14.0    21.0     9.0    5.0    8.0  21.0  10.0  13.0  31.0   4.0
# 2    50.0    44.0    71.0    29.0    5.0    8.0  50.0  31.0  37.0  41.0  41.0
#
#    men6
# 0  16.0
# 1  16.0
# 2  34.0

# %%
# 移動平均
window=7
train_rolling = train_df.rolling(window, min_periods=1).mean()
test_rolling = test_add_pred.rolling(window, min_periods=1).mean()
all_rolling = pd.concat([train_df, test_add_pred], axis=0).reset_index(drop=True).rolling(window, min_periods=1).mean()

# %%
# 目視確認
plot_col = [c for c in train_df.columns if c not in ['id', 'date', 'time', 'year', 'month', 'day', 'weekday']]
ncols = len(plot_col) // 13
plt.subplots(14, ncols, sharey=True, sharex=True, figsize=(30, 80))
for i, col in enumerate(plot_col):
    plt.subplot(14, ncols, i+1)
    plt.plot(train_rolling.index[window:], train_rolling[col][window:], alpha=1, color='blue', label='train')
    plt.plot(all_rolling.index[-len(test_rolling):], all_rolling[col][-len(test_rolling):], alpha=1, color='red', label='test')
    for x in [20,51,81,112,143,173.204,234,265,296,324,350]:
        plt.axvline(x)
    plt.xlabel(col)
    plt.legend()
    plt.xticks([])
plt.show()
