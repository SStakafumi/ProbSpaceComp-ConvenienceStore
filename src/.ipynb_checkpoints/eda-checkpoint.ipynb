# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from pandas_profiling import ProfileReport
#
# File ~/opt/anaconda3/envs/MyPython_01/lib/python3.8/site-packages/pandas_profiling/__init__.py:7, in <module>
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from pandas_profiling.config import Config, config
# ----> 7 from pandas_profiling.controller import pandas_decorator
#       8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#
# File ~/opt/anaconda3/envs/MyPython_01/lib/python3.8/site-packages/pandas_profiling/controller/pandas_decorator.py:4, in <module>
#       1 """This file add the decorator on the DataFrame object."""
# ...
